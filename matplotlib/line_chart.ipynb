# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = [2006 + i for i in range(16)]
y_data = [np.random.randint(70,90) for i in range(16)]
# Out:
# [79, 77, 85, 70, 81, 83, 89, 75, 74, 82, 84, 85, 81, 86, 71, 70]

# %%
#plt.plot(x_data,y_data)
#plt.plot(x_data,y_data,lw=3)
#plt.plot(x_data,y_data,lw=3,ls="--")
plt.plot(x_data,y_data,lw=3,ls="--",c="r")
